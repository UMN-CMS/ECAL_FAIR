# %% [markdown]
# This is the notebook to run the GRU network. It starts with a preprocessed file with p2_calib being the value to predict, and int_deliv_inv_ub and calib_time being the best values to use. It's important to note that at this point, some of the lumi measurements are taken a bit far from the calibration times. this can be seen by the difference between the lumi-section time and the calib_time values. The best data probably just consistents of the points where these are close.
#
# All data is in its original units.
#
# Also, I'm running this in the Python 3.7.1 Kernel

# %%
#import the stuff
import pandas as pd #dataframes etc
import matplotlib.pyplot as plt #plotting
import numpy as np
from sklearn import preprocessing
from common.utils import TimeSeriesTensor, create_evaluation_df, mape, scale_shrinker

# %%
#load the data
test = pd.read_csv('../data/test_diff.csv', index_col=0)
valid = pd.read_csv('../data/valid_diff.csv', index_col=0)
train = pd.read_csv('../data/train_diff.csv', index_col=0)
#set index to datetime periods
#test.index = pd.to_datetime(test.index).to_period('H')
#valid.index = pd.to_datetime(valid.index).to_period('H')
#train.index = pd.to_datetime(train.index).to_period('H')
#set index to datetime
test.index = pd.to_datetime(test.index)
valid.index = pd.to_datetime(valid.index)
train.index = pd.to_datetime(train.index)
train.head()
# Out:
#                            p2  int_deliv_inv_ub
# 2018-05-12 09:01:31  0.000267      1.912590e+07
# 2018-05-12 10:01:31  0.000199      1.786448e+07
# 2018-05-12 11:01:31  0.000203      1.664305e+07
# 2018-05-12 12:01:31  0.000395      3.387666e+07
# 2018-05-12 13:01:31  0.000471      3.200991e+07

# %%
#now we will scale the data
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = StandardScaler()
y_scaler = StandardScaler() #we'll use the y-scaler later
y_scaler.fit(train[['p2']])
train[['p2', 'int_deliv_inv_ub']] = scaler.fit_transform(train)
train.describe()
# Out:
#                  p2  int_deliv_inv_ub
# count  2.655000e+03      2.655000e+03
# mean   3.244946e-17     -1.901597e-16
# std    1.000188e+00      1.000188e+00
# min   -3.961264e+00     -8.967521e-01
# 25%   -2.381792e-01     -8.967502e-01
# 50%    2.085614e-01     -4.075998e-01
# 75%    6.130729e-01      8.383006e-01
# max    2.166144e+00      2.449851e+00

# %%
valid[['p2', 'int_deliv_inv_ub']] = scaler.transform(valid)
valid.describe()
# Out:
#                 p2  int_deliv_inv_ub
# count  1079.000000       1079.000000
# mean      0.019547         -0.047890
# std       0.983953          1.041270
# min      -4.176854         -0.896752
# 25%      -0.104290         -0.896752
# 50%       0.124928         -0.806050
# 75%       0.553043          0.889583
# max       3.153585          2.358973

# %%
test[['p2', 'int_deliv_inv_ub']] = scaler.transform(test)
test.describe()
# Out:
#                 p2  int_deliv_inv_ub
# count  1166.000000       1166.000000
# mean      0.035744         -0.625483
# std       0.604301          0.685445
# min      -3.867696         -0.896752
# 25%      -0.083353         -0.896752
# 50%       0.066339         -0.896752
# 75%       0.261708         -0.896750
# max       2.375856          2.184141

# %%
#number of lag variables and horizon (these are just some starting choices)
T = 10 #the past N hours to study
HORIZON = 1 #predict the next N hours

#sample tensor structure
tensor_structure = {'X':(range(-T+1, 1), ['p2', 'int_deliv_inv_ub'])}

#training tensor
train_input = TimeSeriesTensor(
    dataset=train,
    target="p2",
    H=HORIZON,
    tensor_structure=tensor_structure,
    freq="H", #hours
    drop_incomplete=True, 
)

#validation tensor
valid_inputs = TimeSeriesTensor(valid, "p2", HORIZON, tensor_structure)
print(train_input['X'][0])
print(train_input['target'][0])
train_input['target'].shape
train_input['X'].shape

#print(valid_inputs['X'][0])
#print(valid_inputs['target'][0])
# Out:
# [[ 0.59420064  0.25958877]
#  [ 0.44594011  0.18332401]
#  [ 0.45604353  0.10947734]
#  [ 0.87168012  1.15141108]
#  [ 1.03762608  1.0385484 ]
#  [ 0.68422353  0.92382076]
#  [ 0.38075093  0.62462487]
#  [ 0.89124915  0.35741122]
#  [ 0.32194582  0.3213169 ]
#  [-1.18816483  0.66245371]]
# [-1.67139609]
# (2645, 10, 2)

# %%
#now we bring in the keras tensorflow model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.losses import MeanSquaredLogarithmicError, MeanSquaredError
from tensorflow.keras.utils import plot_model

#from keras_visualizer import visualizer

from math import pow, floor
import time

# %%
# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.00001
    drop = 0.5
    epochs_drop = 200
    lrate = initial_lrate * pow(drop, floor((1+epoch)/epochs_drop))
    return initial_lrate

def my_loss_fn(y_true, y_pred):
    return y_true - y_pred

# %%
#best params:
#Latent_dim:  50 L2 Regularizer:  0.0
#Final Val Loss: 0.14
#optimizer Adam
#batch size 100
#initial rate 0.0001
#drop 0.5
#epochs drop 50
reg_vals = [0.0]
optimizers = ['Adam']
val_results = []
batch_size = [100]
ndims = [50]
losses = [MeanSquaredError()]
for loss in losses:
    for ndim in ndims:
        for reg_val in reg_vals:
            for optimizer in optimizers:
                for batch in batch_size:
                    for i in range(0,1):
                        print('v.',i,'Latent_dim: ',ndim,'L2 Regularizer: ', reg_val,'Optimizer:',optimizer, 'Batch size:',batch)


                        t_start = time.time()
                        LATENT_DIM = ndim
                        BATCH_SIZE = batch
                        EPOCHS = 1000

                        lrate = LearningRateScheduler(step_decay)
                        model = Sequential()
                        model.add(LSTM(LATENT_DIM,return_sequences=True, input_shape=(T, 2), kernel_regularizer=l2(reg_val), recurrent_regularizer=l2(reg_val), bias_regularizer=l2(reg_val)))
                        model.add(LSTM(LATENT_DIM,return_sequences=True, kernel_regularizer=l2(reg_val), recurrent_regularizer=l2(reg_val), bias_regularizer=l2(reg_val)))
                        model.add(LSTM(LATENT_DIM, kernel_regularizer=l2(reg_val), recurrent_regularizer=l2(reg_val), bias_regularizer=l2(reg_val)))
                        #model.add(LSTM(32, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
                        model.add(Dense(HORIZON))
                        model.compile(optimizer=optimizer, loss=loss, 
                                     # metrics=['accuracy']
                                     )

                        earlystop = EarlyStopping(monitor="val_loss", min_delta=0.0, patience=5)
                        model_history = model.fit(
                        train_input["X"],
                        train_input["target"],
                        batch_size=BATCH_SIZE,
                        epochs=EPOCHS,
                        validation_data=(valid_inputs["X"], valid_inputs["target"]),
                        callbacks=[earlystop, lrate],
                        verbose=1,
                        )
                        
                        # list all data in history
                        #print(model_history.history.keys())
                        total_time = time.time()-t_start
                        #make a model picture
                        model.summary()
                        #model_vis = visualizer(model, format='png', view=True)
                        model_vis = plot_model(model, to_file='model.png')
                        # summarize history for loss
                        fig, ax = plt.subplots()
                        ax.plot(model_history.history['loss'])
                        ax.plot(model_history.history['val_loss'])

                        ax.set_ylabel('loss')
                        ax.set_xlabel('epoch')
                        fig.legend(['loss', 'val_loss'], loc='upper left')
                        #plt.show()
                        print('\tFinal Val Loss:',model_history.history['val_loss'][-1],' in: {}s'.format(total_time))
                        if(model_history.history['val_loss'][-1] < 1.0):
                            val_results.append((ndim,reg_val,model_history.history['val_loss'][-1],optimizer,total_time,batch,fig,model_vis))
                        else:
                            plt.close()
# Out:
# v. 0 Latent_dim:  50 L2 Regularizer:  0.0 Optimizer: Adam Batch size: 100
# Epoch 1/1000
# 27/27 [==============================] - 9s 142ms/step - loss: 1.0671 - val_loss: 0.9618
# Epoch 2/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.9953 - val_loss: 0.9579
# Epoch 3/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 1.0580 - val_loss: 0.9544
# Epoch 4/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 1.0254 - val_loss: 0.9510
# Epoch 5/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.9652 - val_loss: 0.9476
# Epoch 6/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.9711 - val_loss: 0.9442
# Epoch 7/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.9996 - val_loss: 0.9410
# Epoch 8/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.9849 - val_loss: 0.9376
# Epoch 9/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.9600 - val_loss: 0.9343
# Epoch 10/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 1.0100 - val_loss: 0.9309
# Epoch 11/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.9944 - val_loss: 0.9276
# Epoch 12/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.9624 - val_loss: 0.9244
# Epoch 13/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.9755 - val_loss: 0.9210
# Epoch 14/1000
# 27/27 [==============================] - 1s 25ms/step - loss: 1.0279 - val_loss: 0.9178
# Epoch 15/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.9512 - val_loss: 0.9144
# Epoch 16/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.9317 - val_loss: 0.9112
# Epoch 17/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.9303 - val_loss: 0.9079
# Epoch 18/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.9564 - val_loss: 0.9047
# Epoch 19/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8887 - val_loss: 0.9016
# Epoch 20/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.9531 - val_loss: 0.8988
# Epoch 21/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.9168 - val_loss: 0.8959
# Epoch 22/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.9045 - val_loss: 0.8936
# Epoch 23/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8801 - val_loss: 0.8913
# Epoch 24/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8717 - val_loss: 0.8893
# Epoch 25/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.9314 - val_loss: 0.8875
# Epoch 26/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.9380 - val_loss: 0.8861
# Epoch 27/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8551 - val_loss: 0.8848
# Epoch 28/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8985 - val_loss: 0.8839
# Epoch 29/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8720 - val_loss: 0.8830
# Epoch 30/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8794 - val_loss: 0.8824
# Epoch 31/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8354 - val_loss: 0.8819
# Epoch 32/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8678 - val_loss: 0.8814
# Epoch 33/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8975 - val_loss: 0.8811
# Epoch 34/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8707 - val_loss: 0.8806
# Epoch 35/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8649 - val_loss: 0.8804
# Epoch 36/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8272 - val_loss: 0.8800
# Epoch 37/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8784 - val_loss: 0.8793
# Epoch 38/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8696 - val_loss: 0.8787
# Epoch 39/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8363 - val_loss: 0.8777
# Epoch 40/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8071 - val_loss: 0.8772
# Epoch 41/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8656 - val_loss: 0.8765
# Epoch 42/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8652 - val_loss: 0.8758
# Epoch 43/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8550 - val_loss: 0.8749
# Epoch 44/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.8800 - val_loss: 0.8738
# Epoch 45/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8496 - val_loss: 0.8728
# Epoch 46/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8518 - val_loss: 0.8716
# Epoch 47/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8569 - val_loss: 0.8708
# Epoch 48/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8289 - val_loss: 0.8698
# Epoch 49/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8590 - val_loss: 0.8691
# Epoch 50/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8563 - val_loss: 0.8679
# Epoch 51/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8183 - val_loss: 0.8667
# Epoch 52/1000
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8244 - val_loss: 0.8658
# Epoch 53/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8184 - val_loss: 0.8643
# Epoch 54/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8170 - val_loss: 0.8636
# Epoch 55/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.8282 - val_loss: 0.8631
# Epoch 56/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8326 - val_loss: 0.8616
# Epoch 57/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8468 - val_loss: 0.8603
# Epoch 58/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8077 - val_loss: 0.8591
# Epoch 59/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7944 - val_loss: 0.8579
# Epoch 60/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8219 - val_loss: 0.8574
# Epoch 61/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8277 - val_loss: 0.8560
# Epoch 62/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8100 - val_loss: 0.8546
# Epoch 63/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.7842 - val_loss: 0.8534
# Epoch 64/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8457 - val_loss: 0.8527
# Epoch 65/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.7802 - val_loss: 0.8514
# Epoch 66/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7779 - val_loss: 0.8503
# Epoch 67/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8272 - val_loss: 0.8493
# Epoch 68/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7695 - val_loss: 0.8482
# Epoch 69/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.7583 - val_loss: 0.8464
# Epoch 70/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.7887 - val_loss: 0.8456
# Epoch 71/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8067 - val_loss: 0.8449
# Epoch 72/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7456 - val_loss: 0.8430
# Epoch 73/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.7902 - val_loss: 0.8421
# Epoch 74/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7891 - val_loss: 0.8411
# Epoch 75/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7585 - val_loss: 0.8400
# Epoch 76/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7798 - val_loss: 0.8392
# Epoch 77/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7859 - val_loss: 0.8375
# Epoch 78/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.7737 - val_loss: 0.8357
# Epoch 79/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7652 - val_loss: 0.8346
# Epoch 80/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.7366 - val_loss: 0.8334
# Epoch 81/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8299 - val_loss: 0.8322
# Epoch 82/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.7792 - val_loss: 0.8311
# Epoch 83/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7491 - val_loss: 0.8299
# Epoch 84/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7462 - val_loss: 0.8286
# Epoch 85/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7648 - val_loss: 0.8270
# Epoch 86/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7520 - val_loss: 0.8259
# Epoch 87/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.7955 - val_loss: 0.8253
# Epoch 88/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7813 - val_loss: 0.8238
# Epoch 89/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7796 - val_loss: 0.8218
# Epoch 90/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7868 - val_loss: 0.8209
# Epoch 91/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7728 - val_loss: 0.8190
# Epoch 92/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7646 - val_loss: 0.8184
# Epoch 93/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7335 - val_loss: 0.8172
# Epoch 94/1000
# 27/27 [==============================] - 1s 38ms/step - loss: 0.7277 - val_loss: 0.8155
# Epoch 95/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7818 - val_loss: 0.8146
# Epoch 96/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7532 - val_loss: 0.8129
# Epoch 97/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7788 - val_loss: 0.8117
# Epoch 98/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7214 - val_loss: 0.8101
# Epoch 99/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.7929 - val_loss: 0.8085
# Epoch 100/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7313 - val_loss: 0.8069
# Epoch 101/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.7266 - val_loss: 0.8050
# Epoch 102/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.7525 - val_loss: 0.8034
# Epoch 103/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7412 - val_loss: 0.8025
# Epoch 104/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.7662 - val_loss: 0.8013
# Epoch 105/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7415 - val_loss: 0.7995
# Epoch 106/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7523 - val_loss: 0.7978
# Epoch 107/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7357 - val_loss: 0.7962
# Epoch 108/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7720 - val_loss: 0.7949
# Epoch 109/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.7276 - val_loss: 0.7924
# Epoch 110/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.6817 - val_loss: 0.7912
# Epoch 111/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.7497 - val_loss: 0.7899
# Epoch 112/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7148 - val_loss: 0.7882
# Epoch 113/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.7226 - val_loss: 0.7867
# Epoch 114/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7788 - val_loss: 0.7851
# Epoch 115/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7371 - val_loss: 0.7831
# Epoch 116/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7503 - val_loss: 0.7811
# Epoch 117/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7148 - val_loss: 0.7796
# Epoch 118/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7575 - val_loss: 0.7785
# Epoch 119/1000
# 27/27 [==============================] - 1s 35ms/step - loss: 0.7151 - val_loss: 0.7765
# Epoch 120/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6793 - val_loss: 0.7742
# Epoch 121/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.7585 - val_loss: 0.7730
# Epoch 122/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7417 - val_loss: 0.7708
# Epoch 123/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7291 - val_loss: 0.7690
# Epoch 124/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.6890 - val_loss: 0.7671
# Epoch 125/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7041 - val_loss: 0.7655
# Epoch 126/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6931 - val_loss: 0.7636
# Epoch 127/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7345 - val_loss: 0.7617
# Epoch 128/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7062 - val_loss: 0.7597
# Epoch 129/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7188 - val_loss: 0.7579
# Epoch 130/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7289 - val_loss: 0.7558
# Epoch 131/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7101 - val_loss: 0.7538
# Epoch 132/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.6779 - val_loss: 0.7522
# Epoch 133/1000
# 27/27 [==============================] - 1s 37ms/step - loss: 0.7351 - val_loss: 0.7502
# Epoch 134/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.6976 - val_loss: 0.7477
# Epoch 135/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.7183 - val_loss: 0.7460
# Epoch 136/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.6903 - val_loss: 0.7440
# Epoch 137/1000
# 27/27 [==============================] - 1s 35ms/step - loss: 0.6739 - val_loss: 0.7416
# Epoch 138/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6760 - val_loss: 0.7394
# Epoch 139/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.6866 - val_loss: 0.7381
# Epoch 140/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6428 - val_loss: 0.7361
# Epoch 141/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6876 - val_loss: 0.7340
# Epoch 142/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6535 - val_loss: 0.7313
# Epoch 143/1000
# 27/27 [==============================] - 1s 36ms/step - loss: 0.7104 - val_loss: 0.7298
# Epoch 144/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.6729 - val_loss: 0.7276
# Epoch 145/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.6782 - val_loss: 0.7253
# Epoch 146/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6531 - val_loss: 0.7228
# Epoch 147/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6830 - val_loss: 0.7209
# Epoch 148/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6507 - val_loss: 0.7191
# Epoch 149/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.6544 - val_loss: 0.7162
# Epoch 150/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.6578 - val_loss: 0.7146
# Epoch 151/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6469 - val_loss: 0.7123
# Epoch 152/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6494 - val_loss: 0.7106
# Epoch 153/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.6769 - val_loss: 0.7082
# Epoch 154/1000
# 27/27 [==============================] - 1s 35ms/step - loss: 0.6664 - val_loss: 0.7055
# Epoch 155/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.6638 - val_loss: 0.7032
# Epoch 156/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.6899 - val_loss: 0.7008
# Epoch 157/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.6512 - val_loss: 0.6989
# Epoch 158/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6398 - val_loss: 0.6967
# Epoch 159/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.6180 - val_loss: 0.6945
# Epoch 160/1000
# 27/27 [==============================] - 1s 35ms/step - loss: 0.6675 - val_loss: 0.6923
# Epoch 161/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.6150 - val_loss: 0.6899
# Epoch 162/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6429 - val_loss: 0.6877
# Epoch 163/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6275 - val_loss: 0.6850
# Epoch 164/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6314 - val_loss: 0.6828
# Epoch 165/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6138 - val_loss: 0.6804
# Epoch 166/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6201 - val_loss: 0.6780
# Epoch 167/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6553 - val_loss: 0.6758
# Epoch 168/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6570 - val_loss: 0.6733
# Epoch 169/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6253 - val_loss: 0.6715
# Epoch 170/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6351 - val_loss: 0.6687
# Epoch 171/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6157 - val_loss: 0.6666
# Epoch 172/1000
# 27/27 [==============================] - 1s 37ms/step - loss: 0.5977 - val_loss: 0.6642
# Epoch 173/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.6001 - val_loss: 0.6620
# Epoch 174/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.6250 - val_loss: 0.6594
# Epoch 175/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6393 - val_loss: 0.6573
# Epoch 176/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5981 - val_loss: 0.6548
# Epoch 177/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5964 - val_loss: 0.6523
# Epoch 178/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5953 - val_loss: 0.6500
# Epoch 179/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.6386 - val_loss: 0.6478
# Epoch 180/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5900 - val_loss: 0.6456
# Epoch 181/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5736 - val_loss: 0.6430
# Epoch 182/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5516 - val_loss: 0.6407
# Epoch 183/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5860 - val_loss: 0.6379
# Epoch 184/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5632 - val_loss: 0.6359
# Epoch 185/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5690 - val_loss: 0.6333
# Epoch 186/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5749 - val_loss: 0.6312
# Epoch 187/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5657 - val_loss: 0.6289
# Epoch 188/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5579 - val_loss: 0.6262
# Epoch 189/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5328 - val_loss: 0.6238
# Epoch 190/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5538 - val_loss: 0.6213
# Epoch 191/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6053 - val_loss: 0.6191
# Epoch 192/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5839 - val_loss: 0.6166
# Epoch 193/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5579 - val_loss: 0.6143
# Epoch 194/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5935 - val_loss: 0.6119
# Epoch 195/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5839 - val_loss: 0.6096
# Epoch 196/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5744 - val_loss: 0.6074
# Epoch 197/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5594 - val_loss: 0.6050
# Epoch 198/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5207 - val_loss: 0.6025
# Epoch 199/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5509 - val_loss: 0.6003
# Epoch 200/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.5433 - val_loss: 0.5977
# Epoch 201/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5629 - val_loss: 0.5959
# Epoch 202/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5898 - val_loss: 0.5932
# Epoch 203/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5418 - val_loss: 0.5910
# Epoch 204/1000
# 27/27 [==============================] - 1s 36ms/step - loss: 0.5735 - val_loss: 0.5887
# Epoch 205/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.5308 - val_loss: 0.5863
# Epoch 206/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5351 - val_loss: 0.5842
# Epoch 207/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5509 - val_loss: 0.5819
# Epoch 208/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.5560 - val_loss: 0.5796
# Epoch 209/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5351 - val_loss: 0.5774
# Epoch 210/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5419 - val_loss: 0.5750
# Epoch 211/1000
# 27/27 [==============================] - 1s 38ms/step - loss: 0.5231 - val_loss: 0.5732
# Epoch 212/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5188 - val_loss: 0.5707
# Epoch 213/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.5320 - val_loss: 0.5690
# Epoch 214/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5174 - val_loss: 0.5667
# Epoch 215/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5252 - val_loss: 0.5641
# Epoch 216/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4817 - val_loss: 0.5621
# Epoch 217/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5270 - val_loss: 0.5598
# Epoch 218/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5402 - val_loss: 0.5576
# Epoch 219/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4935 - val_loss: 0.5552
# Epoch 220/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4939 - val_loss: 0.5533
# Epoch 221/1000
# 27/27 [==============================] - 1s 35ms/step - loss: 0.5023 - val_loss: 0.5507
# Epoch 222/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4944 - val_loss: 0.5491
# Epoch 223/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4871 - val_loss: 0.5467
# Epoch 224/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4685 - val_loss: 0.5449
# Epoch 225/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4820 - val_loss: 0.5427
# Epoch 226/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4945 - val_loss: 0.5403
# Epoch 227/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.5224 - val_loss: 0.5384
# Epoch 228/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5209 - val_loss: 0.5363
# Epoch 229/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4882 - val_loss: 0.5343
# Epoch 230/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4958 - val_loss: 0.5323
# Epoch 231/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4898 - val_loss: 0.5301
# Epoch 232/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4710 - val_loss: 0.5280
# Epoch 233/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4891 - val_loss: 0.5262
# Epoch 234/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4807 - val_loss: 0.5240
# Epoch 235/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.5015 - val_loss: 0.5223
# Epoch 236/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4805 - val_loss: 0.5199
# Epoch 237/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4912 - val_loss: 0.5179
# Epoch 238/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4675 - val_loss: 0.5159
# Epoch 239/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4439 - val_loss: 0.5142
# Epoch 240/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4554 - val_loss: 0.5124
# Epoch 241/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4663 - val_loss: 0.5107
# Epoch 242/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4764 - val_loss: 0.5086
# Epoch 243/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4737 - val_loss: 0.5067
# Epoch 244/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4512 - val_loss: 0.5046
# Epoch 245/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4437 - val_loss: 0.5028
# Epoch 246/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4494 - val_loss: 0.5009
# Epoch 247/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4856 - val_loss: 0.4991
# Epoch 248/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4363 - val_loss: 0.4970
# Epoch 249/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4401 - val_loss: 0.4955
# Epoch 250/1000
# 27/27 [==============================] - 1s 39ms/step - loss: 0.4766 - val_loss: 0.4933
# Epoch 251/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4488 - val_loss: 0.4917
# Epoch 252/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4663 - val_loss: 0.4902
# Epoch 253/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4557 - val_loss: 0.4878
# Epoch 254/1000
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4606 - val_loss: 0.4863
# Epoch 255/1000
# 27/27 [==============================] - 1s 37ms/step - loss: 0.4461 - val_loss: 0.4840
# Epoch 256/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4635 - val_loss: 0.4824
# Epoch 257/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4399 - val_loss: 0.4807
# Epoch 258/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4336 - val_loss: 0.4787
# Epoch 259/1000
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4564 - val_loss: 0.4769
# Epoch 260/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4134 - val_loss: 0.4753
# Epoch 261/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4397 - val_loss: 0.4733
# Epoch 262/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4162 - val_loss: 0.4718
# Epoch 263/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4138 - val_loss: 0.4696
# Epoch 264/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4344 - val_loss: 0.4678
# Epoch 265/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4162 - val_loss: 0.4661
# Epoch 266/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4358 - val_loss: 0.4644
# Epoch 267/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4399 - val_loss: 0.4626
# Epoch 268/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4460 - val_loss: 0.4611
# Epoch 269/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4054 - val_loss: 0.4593
# Epoch 270/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4517 - val_loss: 0.4577
# Epoch 271/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4126 - val_loss: 0.4558
# Epoch 272/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4115 - val_loss: 0.4542
# Epoch 273/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4315 - val_loss: 0.4523
# Epoch 274/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4080 - val_loss: 0.4505
# Epoch 275/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4215 - val_loss: 0.4487
# Epoch 276/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4162 - val_loss: 0.4473
# Epoch 277/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4155 - val_loss: 0.4451
# Epoch 278/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4210 - val_loss: 0.4436
# Epoch 279/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.4034 - val_loss: 0.4419
# Epoch 280/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4046 - val_loss: 0.4402
# Epoch 281/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4175 - val_loss: 0.4388
# Epoch 282/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4020 - val_loss: 0.4373
# Epoch 283/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.4074 - val_loss: 0.4355
# Epoch 284/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3768 - val_loss: 0.4342
# Epoch 285/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3947 - val_loss: 0.4325
# Epoch 286/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.4076 - val_loss: 0.4308
# Epoch 287/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3926 - val_loss: 0.4289
# Epoch 288/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.4084 - val_loss: 0.4276
# Epoch 289/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4166 - val_loss: 0.4254
# Epoch 290/1000
# 27/27 [==============================] - 1s 25ms/step - loss: 0.4075 - val_loss: 0.4240
# Epoch 291/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3999 - val_loss: 0.4226
# Epoch 292/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3900 - val_loss: 0.4212
# Epoch 293/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3777 - val_loss: 0.4195
# Epoch 294/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.4051 - val_loss: 0.4179
# Epoch 295/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3883 - val_loss: 0.4161
# Epoch 296/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.4099 - val_loss: 0.4149
# Epoch 297/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3787 - val_loss: 0.4131
# Epoch 298/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3894 - val_loss: 0.4117
# Epoch 299/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3743 - val_loss: 0.4101
# Epoch 300/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3929 - val_loss: 0.4086
# Epoch 301/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3599 - val_loss: 0.4072
# Epoch 302/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.3659 - val_loss: 0.4055
# Epoch 303/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3946 - val_loss: 0.4041
# Epoch 304/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3615 - val_loss: 0.4026
# Epoch 305/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.3806 - val_loss: 0.4012
# Epoch 306/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3763 - val_loss: 0.3995
# Epoch 307/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3895 - val_loss: 0.3980
# Epoch 308/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3831 - val_loss: 0.3963
# Epoch 309/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3707 - val_loss: 0.3948
# Epoch 310/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3768 - val_loss: 0.3935
# Epoch 311/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3477 - val_loss: 0.3920
# Epoch 312/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3763 - val_loss: 0.3905
# Epoch 313/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3563 - val_loss: 0.3891
# Epoch 314/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3644 - val_loss: 0.3878
# Epoch 315/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3588 - val_loss: 0.3866
# Epoch 316/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3534 - val_loss: 0.3851
# Epoch 317/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3777 - val_loss: 0.3839
# Epoch 318/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3420 - val_loss: 0.3825
# Epoch 319/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3511 - val_loss: 0.3808
# Epoch 320/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3550 - val_loss: 0.3792
# Epoch 321/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3560 - val_loss: 0.3780
# Epoch 322/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3328 - val_loss: 0.3762
# Epoch 323/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3571 - val_loss: 0.3749
# Epoch 324/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3505 - val_loss: 0.3735
# Epoch 325/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3443 - val_loss: 0.3721
# Epoch 326/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3266 - val_loss: 0.3711
# Epoch 327/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3797 - val_loss: 0.3696
# Epoch 328/1000
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3597 - val_loss: 0.3685
# Epoch 329/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3287 - val_loss: 0.3669
# Epoch 330/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3205 - val_loss: 0.3658
# Epoch 331/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3145 - val_loss: 0.3644
# Epoch 332/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3328 - val_loss: 0.3632
# Epoch 333/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3386 - val_loss: 0.3618
# Epoch 334/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3500 - val_loss: 0.3607
# Epoch 335/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3284 - val_loss: 0.3593
# Epoch 336/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3410 - val_loss: 0.3578
# Epoch 337/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3425 - val_loss: 0.3569
# Epoch 338/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3181 - val_loss: 0.3555
# Epoch 339/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3439 - val_loss: 0.3545
# Epoch 340/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3142 - val_loss: 0.3531
# Epoch 341/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3426 - val_loss: 0.3522
# Epoch 342/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3293 - val_loss: 0.3506
# Epoch 343/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3350 - val_loss: 0.3498
# Epoch 344/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3312 - val_loss: 0.3482
# Epoch 345/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3054 - val_loss: 0.3472
# Epoch 346/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3258 - val_loss: 0.3462
# Epoch 347/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3074 - val_loss: 0.3448
# Epoch 348/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3287 - val_loss: 0.3436
# Epoch 349/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2997 - val_loss: 0.3424
# Epoch 350/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3175 - val_loss: 0.3418
# Epoch 351/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3158 - val_loss: 0.3403
# Epoch 352/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3074 - val_loss: 0.3390
# Epoch 353/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3107 - val_loss: 0.3382
# Epoch 354/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3024 - val_loss: 0.3371
# Epoch 355/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3241 - val_loss: 0.3357
# Epoch 356/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3112 - val_loss: 0.3347
# Epoch 357/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3104 - val_loss: 0.3338
# Epoch 358/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2855 - val_loss: 0.3325
# Epoch 359/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3140 - val_loss: 0.3317
# Epoch 360/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3063 - val_loss: 0.3304
# Epoch 361/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2886 - val_loss: 0.3295
# Epoch 362/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2958 - val_loss: 0.3283
# Epoch 363/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2935 - val_loss: 0.3273
# Epoch 364/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3262 - val_loss: 0.3263
# Epoch 365/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3007 - val_loss: 0.3251
# Epoch 366/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3097 - val_loss: 0.3241
# Epoch 367/1000
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3042 - val_loss: 0.3233
# Epoch 368/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2817 - val_loss: 0.3221
# Epoch 369/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3007 - val_loss: 0.3211
# Epoch 370/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3086 - val_loss: 0.3201
# Epoch 371/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3003 - val_loss: 0.3192
# Epoch 372/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2954 - val_loss: 0.3181
# Epoch 373/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2741 - val_loss: 0.3174
# Epoch 374/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2900 - val_loss: 0.3161
# Epoch 375/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2936 - val_loss: 0.3153
# Epoch 376/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2917 - val_loss: 0.3145
# Epoch 377/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2852 - val_loss: 0.3134
# Epoch 378/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2850 - val_loss: 0.3128
# Epoch 379/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2929 - val_loss: 0.3119
# Epoch 380/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2745 - val_loss: 0.3108
# Epoch 381/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2688 - val_loss: 0.3098
# Epoch 382/1000
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2755 - val_loss: 0.3089
# Epoch 383/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2620 - val_loss: 0.3080
# Epoch 384/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2882 - val_loss: 0.3070
# Epoch 385/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2880 - val_loss: 0.3058
# Epoch 386/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.3030 - val_loss: 0.3052
# Epoch 387/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2735 - val_loss: 0.3043
# Epoch 388/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2755 - val_loss: 0.3034
# Epoch 389/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2811 - val_loss: 0.3025
# Epoch 390/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2786 - val_loss: 0.3017
# Epoch 391/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2629 - val_loss: 0.3008
# Epoch 392/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2678 - val_loss: 0.3000
# Epoch 393/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2616 - val_loss: 0.2990
# Epoch 394/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2950 - val_loss: 0.2983
# Epoch 395/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2548 - val_loss: 0.2973
# Epoch 396/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2528 - val_loss: 0.2967
# Epoch 397/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2745 - val_loss: 0.2956
# Epoch 398/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2584 - val_loss: 0.2952
# Epoch 399/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2659 - val_loss: 0.2941
# Epoch 400/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2801 - val_loss: 0.2934
# Epoch 401/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2654 - val_loss: 0.2925
# Epoch 402/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2579 - val_loss: 0.2916
# Epoch 403/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2632 - val_loss: 0.2908
# Epoch 404/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2562 - val_loss: 0.2902
# Epoch 405/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2689 - val_loss: 0.2892
# Epoch 406/1000
# 27/27 [==============================] - 1s 35ms/step - loss: 0.2470 - val_loss: 0.2883
# Epoch 407/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2585 - val_loss: 0.2878
# Epoch 408/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2486 - val_loss: 0.2866
# Epoch 409/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2580 - val_loss: 0.2863
# Epoch 410/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2708 - val_loss: 0.2853
# Epoch 411/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2469 - val_loss: 0.2847
# Epoch 412/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2569 - val_loss: 0.2839
# Epoch 413/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2699 - val_loss: 0.2829
# Epoch 414/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2586 - val_loss: 0.2820
# Epoch 415/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2611 - val_loss: 0.2815
# Epoch 416/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2481 - val_loss: 0.2809
# Epoch 417/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2497 - val_loss: 0.2800
# Epoch 418/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2617 - val_loss: 0.2792
# Epoch 419/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2587 - val_loss: 0.2783
# Epoch 420/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2476 - val_loss: 0.2779
# Epoch 421/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2476 - val_loss: 0.2773
# Epoch 422/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2381 - val_loss: 0.2763
# Epoch 423/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2516 - val_loss: 0.2757
# Epoch 424/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2614 - val_loss: 0.2744
# Epoch 425/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2454 - val_loss: 0.2740
# Epoch 426/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2323 - val_loss: 0.2732
# Epoch 427/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2252 - val_loss: 0.2729
# Epoch 428/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2353 - val_loss: 0.2720
# Epoch 429/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2398 - val_loss: 0.2712
# Epoch 430/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2497 - val_loss: 0.2705
# Epoch 431/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2554 - val_loss: 0.2697
# Epoch 432/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2449 - val_loss: 0.2690
# Epoch 433/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2358 - val_loss: 0.2682
# Epoch 434/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2369 - val_loss: 0.2677
# Epoch 435/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2647 - val_loss: 0.2668
# Epoch 436/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2298 - val_loss: 0.2662
# Epoch 437/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2533 - val_loss: 0.2653
# Epoch 438/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2316 - val_loss: 0.2647
# Epoch 439/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2279 - val_loss: 0.2639
# Epoch 440/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2343 - val_loss: 0.2631
# Epoch 441/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2312 - val_loss: 0.2625
# Epoch 442/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2280 - val_loss: 0.2618
# Epoch 443/1000
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2374 - val_loss: 0.2610
# Epoch 444/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2381 - val_loss: 0.2603
# Epoch 445/1000
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2428 - val_loss: 0.2598
# Epoch 446/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2225 - val_loss: 0.2591
# Epoch 447/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2334 - val_loss: 0.2584
# Epoch 448/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2329 - val_loss: 0.2575
# Epoch 449/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2341 - val_loss: 0.2569
# Epoch 450/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2350 - val_loss: 0.2562
# Epoch 451/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2230 - val_loss: 0.2556
# Epoch 452/1000
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2370 - val_loss: 0.2547
# Epoch 453/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2159 - val_loss: 0.2543
# Epoch 454/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2333 - val_loss: 0.2535
# Epoch 455/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2333 - val_loss: 0.2526
# Epoch 456/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2382 - val_loss: 0.2521
# Epoch 457/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2327 - val_loss: 0.2515
# Epoch 458/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2115 - val_loss: 0.2506
# Epoch 459/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2241 - val_loss: 0.2503
# Epoch 460/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2228 - val_loss: 0.2494
# Epoch 461/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2118 - val_loss: 0.2487
# Epoch 462/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2105 - val_loss: 0.2481
# Epoch 463/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2308 - val_loss: 0.2474
# Epoch 464/1000
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2248 - val_loss: 0.2468
# Epoch 465/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2222 - val_loss: 0.2460
# Epoch 466/1000
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2171 - val_loss: 0.2456
# Epoch 467/1000
# ...
# Epoch 690/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1438 - val_loss: 0.1495
# Epoch 691/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1505 - val_loss: 0.1492
# Epoch 692/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1468 - val_loss: 0.1490
# Epoch 693/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1438 - val_loss: 0.1489
# Epoch 694/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1415 - val_loss: 0.1488
# Epoch 695/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1380 - val_loss: 0.1486
# Epoch 696/1000
# 27/27 [==============================] - 1s 23ms/step - loss: 0.1445 - val_loss: 0.1486
# Epoch 697/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1451 - val_loss: 0.1483
# Epoch 698/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1375 - val_loss: 0.1483
# Epoch 699/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1438 - val_loss: 0.1482
# Epoch 700/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1396 - val_loss: 0.1480
# Epoch 701/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1352 - val_loss: 0.1479
# Epoch 702/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1375 - val_loss: 0.1477
# Epoch 703/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1443 - val_loss: 0.1475
# Epoch 704/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1412 - val_loss: 0.1473
# Epoch 705/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1348 - val_loss: 0.1471
# Epoch 706/1000
# 27/27 [==============================] - 0s 19ms/step - loss: 0.1372 - val_loss: 0.1471
# Epoch 707/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1459 - val_loss: 0.1470
# Epoch 708/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1445 - val_loss: 0.1468
# Epoch 709/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1416 - val_loss: 0.1468
# Epoch 710/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1339 - val_loss: 0.1467
# Epoch 711/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1460 - val_loss: 0.1464
# Epoch 712/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1414 - val_loss: 0.1464
# Epoch 713/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1600 - val_loss: 0.1463
# Epoch 714/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1424 - val_loss: 0.1462
# Epoch 715/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1440 - val_loss: 0.1459
# Epoch 716/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1405 - val_loss: 0.1459
# Epoch 717/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1265 - val_loss: 0.1458
# Epoch 718/1000
# 27/27 [==============================] - 1s 23ms/step - loss: 0.1511 - val_loss: 0.1455
# Epoch 719/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1356 - val_loss: 0.1456
# Epoch 720/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1534 - val_loss: 0.1454
# Epoch 721/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1447 - val_loss: 0.1453
# Epoch 722/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1500 - val_loss: 0.1454
# Epoch 723/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1458 - val_loss: 0.1452
# Epoch 724/1000
# 27/27 [==============================] - 0s 19ms/step - loss: 0.1410 - val_loss: 0.1449
# Epoch 725/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1444 - val_loss: 0.1448
# Epoch 726/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1426 - val_loss: 0.1448
# Epoch 727/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1499 - val_loss: 0.1446
# Epoch 728/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1371 - val_loss: 0.1446
# Epoch 729/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1487 - val_loss: 0.1444
# Epoch 730/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1456 - val_loss: 0.1444
# Epoch 731/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1354 - val_loss: 0.1444
# Epoch 732/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1449 - val_loss: 0.1443
# Epoch 733/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1392 - val_loss: 0.1442
# Epoch 734/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1400 - val_loss: 0.1439
# Epoch 735/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1495 - val_loss: 0.1439
# Epoch 736/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1381 - val_loss: 0.1438
# Epoch 737/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1433 - val_loss: 0.1438
# Epoch 738/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1458 - val_loss: 0.1437
# Epoch 739/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1382 - val_loss: 0.1436
# Epoch 740/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1426 - val_loss: 0.1434
# Epoch 741/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1452 - val_loss: 0.1433
# Epoch 742/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1503 - val_loss: 0.1432
# Epoch 743/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1412 - val_loss: 0.1432
# Epoch 744/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1389 - val_loss: 0.1431
# Epoch 745/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1411 - val_loss: 0.1430
# Epoch 746/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1449 - val_loss: 0.1429
# Epoch 747/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1431 - val_loss: 0.1429
# Epoch 748/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1351 - val_loss: 0.1427
# Epoch 749/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1406 - val_loss: 0.1426
# Epoch 750/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1407 - val_loss: 0.1426
# Epoch 751/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1468 - val_loss: 0.1426
# Epoch 752/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1385 - val_loss: 0.1425
# Epoch 753/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1348 - val_loss: 0.1423
# Epoch 754/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1307 - val_loss: 0.1423
# Epoch 755/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1552 - val_loss: 0.1422
# Epoch 756/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1392 - val_loss: 0.1425
# Epoch 757/1000
# 27/27 [==============================] - 1s 23ms/step - loss: 0.1467 - val_loss: 0.1422
# Epoch 758/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1400 - val_loss: 0.1421
# Epoch 759/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1380 - val_loss: 0.1419
# Epoch 760/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1401 - val_loss: 0.1420
# Epoch 761/1000
# 27/27 [==============================] - 0s 19ms/step - loss: 0.1430 - val_loss: 0.1419
# Epoch 762/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1374 - val_loss: 0.1419
# Epoch 763/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1332 - val_loss: 0.1418
# Epoch 764/1000
# 27/27 [==============================] - 1s 24ms/step - loss: 0.1437 - val_loss: 0.1419
# Epoch 765/1000
# 27/27 [==============================] - 1s 23ms/step - loss: 0.1519 - val_loss: 0.1417
# Epoch 766/1000
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1313 - val_loss: 0.1416
# Epoch 767/1000
# 27/27 [==============================] - 1s 23ms/step - loss: 0.1438 - val_loss: 0.1415
# Epoch 768/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1392 - val_loss: 0.1414
# Epoch 769/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1407 - val_loss: 0.1415
# Epoch 770/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1523 - val_loss: 0.1412
# Epoch 771/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1408 - val_loss: 0.1412
# Epoch 772/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1379 - val_loss: 0.1411
# Epoch 773/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1391 - val_loss: 0.1412
# Epoch 774/1000
# 27/27 [==============================] - 1s 24ms/step - loss: 0.1442 - val_loss: 0.1411
# Epoch 775/1000
# 27/27 [==============================] - 1s 23ms/step - loss: 0.1355 - val_loss: 0.1410
# Epoch 776/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1370 - val_loss: 0.1408
# Epoch 777/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1395 - val_loss: 0.1411
# Epoch 778/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1392 - val_loss: 0.1409
# Epoch 779/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1321 - val_loss: 0.1407
# Epoch 780/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1397 - val_loss: 0.1408
# Epoch 781/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1538 - val_loss: 0.1409
# Epoch 782/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1367 - val_loss: 0.1406
# Epoch 783/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1360 - val_loss: 0.1406
# Epoch 784/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1481 - val_loss: 0.1405
# Epoch 785/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1365 - val_loss: 0.1406
# Epoch 786/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1254 - val_loss: 0.1405
# Epoch 787/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1329 - val_loss: 0.1405
# Epoch 788/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1531 - val_loss: 0.1403
# Epoch 789/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1382 - val_loss: 0.1404
# Epoch 790/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1371 - val_loss: 0.1404
# Epoch 791/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1604 - val_loss: 0.1403
# Epoch 792/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1331 - val_loss: 0.1401
# Epoch 793/1000
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1377 - val_loss: 0.1402
# Epoch 794/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1285 - val_loss: 0.1401
# Epoch 795/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1437 - val_loss: 0.1399
# Epoch 796/1000
# 27/27 [==============================] - 1s 24ms/step - loss: 0.1469 - val_loss: 0.1399
# Epoch 797/1000
# 27/27 [==============================] - 0s 19ms/step - loss: 0.1340 - val_loss: 0.1399
# Epoch 798/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1414 - val_loss: 0.1399
# Epoch 799/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1377 - val_loss: 0.1399
# Epoch 800/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1360 - val_loss: 0.1400
# Epoch 801/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1404 - val_loss: 0.1398
# Epoch 802/1000
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1361 - val_loss: 0.1398
# Epoch 803/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1367 - val_loss: 0.1400
# Epoch 804/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1441 - val_loss: 0.1398
# Epoch 805/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1317 - val_loss: 0.1398
# Epoch 806/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1317 - val_loss: 0.1398
# Epoch 807/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1360 - val_loss: 0.1395
# Epoch 808/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1376 - val_loss: 0.1396
# Epoch 809/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1317 - val_loss: 0.1396
# Epoch 810/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1397 - val_loss: 0.1396
# Epoch 811/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1332 - val_loss: 0.1396
# Epoch 812/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1493 - val_loss: 0.1393
# Epoch 813/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1396 - val_loss: 0.1394
# Epoch 814/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1431 - val_loss: 0.1393
# Epoch 815/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1309 - val_loss: 0.1392
# Epoch 816/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1279 - val_loss: 0.1392
# Epoch 817/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1340 - val_loss: 0.1391
# Epoch 818/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1275 - val_loss: 0.1393
# Epoch 819/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1358 - val_loss: 0.1393
# Epoch 820/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1319 - val_loss: 0.1392
# Epoch 821/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1451 - val_loss: 0.1391
# Epoch 822/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1410 - val_loss: 0.1390
# Epoch 823/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1328 - val_loss: 0.1390
# Epoch 824/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1403 - val_loss: 0.1391
# Epoch 825/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1340 - val_loss: 0.1389
# Epoch 826/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1387 - val_loss: 0.1391
# Epoch 827/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1314 - val_loss: 0.1389
# Epoch 828/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1418 - val_loss: 0.1387
# Epoch 829/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1508 - val_loss: 0.1390
# Epoch 830/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1431 - val_loss: 0.1389
# Epoch 831/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1407 - val_loss: 0.1388
# Epoch 832/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1347 - val_loss: 0.1388
# Epoch 833/1000
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1347 - val_loss: 0.1388
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 50)            10600
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 50)            20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 51,051
# Trainable params: 51,051
# Non-trainable params: 0
# _________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# 	Final Val Loss: 0.13875432312488556  in: 587.3451082706451s

# %%
#for result in val_results:
  #  print("ndim: ",result[0])
  #  print("reg_val: ",result[1])
  #  print("val_loss: ",result[2])
  #  print("optimizer: ",result[3])
df_results = pd.DataFrame(val_results, columns=['hidden_dimensions','L2_reg_val','final_val_loss','optimizer','training_time','batch_size','FIG','MODEL_VIS'])
res_grps = df_results.groupby('batch_size')
for batch in batch_size:
    print('Batch size: {}'.format(batch))
    df_batch = res_grps.get_group(batch).drop(['batch_size','hidden_dimensions','L2_reg_val'],axis=1)
    print('\tAvg final val loss: {:.2f}+-{:.2f}'.format(df_batch.final_val_loss.mean(),df_batch.final_val_loss.std()))
    print('\tAvg training time: {:.2f}+-{:.2f}'.format(df_batch.training_time.mean(),df_batch.training_time.std()))
    
for count,result in enumerate(val_results):
    result[-1].savefig('loss-curve_batch-size_{}_{}.png'.format(result[-4],count))
# Out:
# Batch size: 100
# 	Avg final val loss: 0.14+-nan
# 	Avg training time: 587.35+-nan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-0cd6637165d2> in <module>
#      13
#      14 for count,result in enumerate(val_results):
# ---> 15     result[-1].savefig('loss-curve_batch-size_{}_{}.png'.format(result[-4],count))
#
# AttributeError: 'NoneType' object has no attribute 'savefig'

# %%
df_results
# Out:
#    hidden_dimensions  L2_reg_val  final_val_loss optimizer  training_time  \
# 0                 50         0.0        0.138754      Adam     587.345108
#
#    batch_size              FIG MODEL_VIS
# 0         100  Figure(432x288)      None

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('mean squared-error')
plt.xlabel('epoch')
plt.legend(['training loss', 'validation loss'], loc='upper right')
plt.show()

# %%
#now we'll test
data_test_inputs = TimeSeriesTensor(test, "p2", HORIZON, tensor_structure)
#print(data_test_inputs['X'][0])
#print(data_test_inputs['target'][0])

predictions = model.predict(data_test_inputs["X"])
#print(predictions)
ev_data = create_evaluation_df(predictions, data_test_inputs, HORIZON, y_scaler)
ev_groups = ev_data.groupby('h')
#test.head()
gr1 = ev_groups.get_group('t+1')

# %%
gr1.describe()
# Out:
#         prediction       actual
# count  1156.000000  1156.000000
# mean      0.000008     0.000010
# std       0.000257     0.000279
# min      -0.001488    -0.001788
# 25%      -0.000058    -0.000045
# 50%       0.000022     0.000024
# 75%       0.000124     0.000114
# max       0.000807     0.001087

# %%
apes = []
for i in range(0, gr1.prediction.count()):
    if gr1.actual.iloc[i] == 0:
        continue
    ape = abs((gr1.prediction.iloc[i] - gr1.actual.iloc[i]) / gr1.actual.iloc[i])
    apes.append(ape)
    
mape1 = (sum(apes) / len(apes))

print('Evaluating GRU')
print("MAPE prediction 1 hour  ahead: {:.2%}".format(mape1))
# Out:
# Evaluating GRU
# MAPE prediction 1 hour  ahead: 319.97%

# %%
#lets plot our results
fig, ax = plt.subplots(figsize=(25,5))

ev_group = ev_groups.get_group('t+1')

ax.set_title('{time:.0f} hours predicting next 1 hour'.format(time=T))
ax.set_ylabel('calibration change')
ax.set_xlabel('FED firing time')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

ax.plot(ev_group.timestamp, ev_group.actual, 
         label='actual calibration', color='blue', linewidth=1, linestyle='solid')

ax.plot(ev_group.timestamp, ev_group.prediction, 
         label='predicted calibration', color='red', linewidth=1, linestyle='solid')
#legend
fig.legend(ncol=1, loc = (0.8,0.2))
fig.show()

# %%
####MAKE DIFF PLOT########
apdiff_series = ((ev_group.actual - ev_group.prediction) / ev_group.actual).abs()
fig3, ax3 = plt.subplots(figsize=(15,5))

ax3.set_ylabel('| Actual - Prediction / Actual |')
ax3.set_xlabel('FED firing time')
plt.setp(ax3.get_xticklabels(), rotation=30, horizontalalignment='right')

#actual data
ax3.plot(ev_group.timestamp, apdiff_series, 
     label='True value', color='green', linewidth=1, linestyle='solid')
#legend
fig3.legend(ncol=3, loc = 'upper center')

# %%
#our data is transformed to feed into the model. The diff step transforms the data by removing the large scale trends. We'll run that in reverse to look at the data with the trends.
ev_data_int = ev_data.copy()
ev_data_int['prediction'] = ev_data_int['prediction'].cumsum()
ev_data_int['actual'] = ev_data_int['actual'].cumsum()
ev_data.head()
# Out:
#             timestamp    h  prediction    actual
# 0 2018-10-15 10:36:23  t+1    0.000084  0.000081
# 1 2018-10-15 11:36:23  t+1    0.000067  0.000172
# 2 2018-10-15 12:36:23  t+1    0.000174  0.000134
# 3 2018-10-15 13:36:23  t+1    0.000100  0.000119
# 4 2018-10-15 14:36:23  t+1    0.000095  0.000161

# %%
#lets plot our results
fig10, ax13 = plt.subplots(figsize=(15,5))

ax13.set_title('{time:.0f} hours predicting next hour'.format(time=T))
ax13.set_ylabel('calibration value minus initial')
ax13.set_xlabel('calibration time')
plt.setp(ax13.get_xticklabels(), rotation=30, horizontalalignment='right')

ax13.plot(ev_data_int.timestamp, ev_data_int.actual, 
         label='actual calibration', color='blue', linewidth=2, linestyle='solid')

ax13.plot(ev_data_int.timestamp, ev_data_int.prediction, 
         label='predicted calibration', color='red', linewidth=2, linestyle='solid')

#lumi data on alternate y axis
#ax14 = ax13.twinx()
#ax14.set_ylabel('integrated luminosity (/ub)')
#
#ax14.plot(test_lumi_avg.index, test_lumi_avg, 
#         label='lumi averaged', color='limegreen', linewidth=1, linestyle='dashed')

#legend
fig10.legend(ncol=1, loc=(0.8,0.2))
#plt.ylim([-.05, ev_data_int.actual.max()*1.1])
fig10.show()
# Out:
# /home/rusack/evans908/.local/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /home/rusack/evans908/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /home/rusack/evans908/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
apes = []
for i in range(0, gr1.prediction.count()):
    if gr1.actual.iloc[i] == 0:
        continue
    ape = abs((gr1.prediction.iloc[i] - gr1.actual.iloc[i]) / gr1.actual.iloc[i])
    apes.append(ape)
    
mape1 = (sum(apes) / len(apes))
mape1
# Out:
# 3.199726523663976

# %% [markdown]
# This is the notebook to run the GRU network. It starts with a preprocessed file with p2_calib being the value to predict, and int_deliv_inv_ub and calib_time being the best values to use. It's important to note that at this point, some of the lumi measurements are taken a bit far from the calibration times. this can be seen by the difference between the lumi-section time and the calib_time values. The best data probably just consistents of the points where these are close.
#
# All data is in its original units.
#
# Also, I'm running this in the Python 3.7.1 Kernel

# %%
#import the stuff
import pandas as pd #dataframes etc
import matplotlib.pyplot as plt #plotting
import numpy as np
from sklearn import preprocessing
from common.utils import TimeSeriesTensor, create_evaluation_df, mape, scale_shrinker

# %%
#load the data
test = pd.read_csv('../data/test_diff.csv', index_col=0)
valid = pd.read_csv('../data/valid_diff.csv', index_col=0)
train = pd.read_csv('../data/train_diff.csv', index_col=0)
#set index to datetime periods
#test.index = pd.to_datetime(test.index).to_period('H')
#valid.index = pd.to_datetime(valid.index).to_period('H')
#train.index = pd.to_datetime(train.index).to_period('H')
#set index to datetime
test.index = pd.to_datetime(test.index)
valid.index = pd.to_datetime(valid.index)
train.index = pd.to_datetime(train.index)
train.head()
# Out:
#                            p2  int_deliv_inv_ub
# 2018-06-22 18:39:44  0.000039       6637.554405
# 2018-06-22 19:39:44 -0.000029       6028.089283
# 2018-06-22 20:39:44  0.000052       4197.100697
# 2018-06-22 21:39:44  0.000066       6308.041306
# 2018-06-22 22:39:44  0.000060       6308.041313

# %%
#now we will scale the data
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = StandardScaler()
y_scaler = StandardScaler() #we'll use the y-scaler later
y_scaler.fit(train[['p2']])
train[['p2', 'int_deliv_inv_ub']] = scaler.fit_transform(train)
train.describe()
# Out:
#                  p2  int_deliv_inv_ub
# count  1.981000e+03      1.981000e+03
# mean   1.675703e-17      6.755491e-16
# std    1.000252e+00      1.000252e+00
# min   -3.959721e+00     -9.459218e-01
# 25%   -3.061145e-01     -9.456447e-01
# 50%    2.263512e-01     -2.924884e-01
# 75%    6.040580e-01      8.534767e-01
# max    2.018919e+00      2.202867e+00

# %%
valid[['p2', 'int_deliv_inv_ub']] = scaler.transform(valid)
valid.describe()
# Out:
#                p2  int_deliv_inv_ub
# count  813.000000        813.000000
# mean    -0.015470         -0.016140
# std      1.111188          1.000044
# min     -4.168876         -0.945922
# 25%     -0.318478         -0.945922
# 50%      0.208617         -0.361363
# 75%      0.645773          0.906174
# max      3.149370          2.170162

# %%
test[['p2', 'int_deliv_inv_ub']] = scaler.transform(test)
test.describe()
# Out:
#                p2  int_deliv_inv_ub
# count  839.000000        839.000000
# mean     0.084151         -0.944355
# std      0.254370          0.012042
# min     -0.610920         -0.945922
# 25%     -0.081761         -0.945922
# 50%      0.078562         -0.945922
# 75%      0.236518         -0.945921
# max      1.576933         -0.821779

# %%
#number of lag variables and horizon (these are just some starting choices)
T = 10 #the past N hours to study
HORIZON = 1 #predict the next N hours

#sample tensor structure
tensor_structure = {'X':(range(-T+1, 1), ['p2', 'int_deliv_inv_ub'])}

#training tensor
train_input = TimeSeriesTensor(
    dataset=train,
    target="p2",
    H=HORIZON,
    tensor_structure=tensor_structure,
    freq="H", #hours
    drop_incomplete=True, 
)

#validation tensor
valid_inputs = TimeSeriesTensor(valid, "p2", HORIZON, tensor_structure)
print(train_input['X'][0])
print(train_input['target'][0])
train_input['target'].shape
train_input['X'].shape

#print(valid_inputs['X'][0])
#print(valid_inputs['target'][0])
# Out:
# [[ 0.1102464  -0.94552794]
#  [-0.03826301 -0.94556411]
#  [ 0.13761956 -0.94567274]
#  [ 0.16853182 -0.9455475 ]
#  [ 0.1554102  -0.9455475 ]
#  [ 0.01601738 -0.9455475 ]
#  [ 0.22536023 -0.94581004]
#  [ 0.20284247 -0.94591118]
#  [ 0.24617286 -0.94592177]
#  [ 0.09996933 -0.94592177]]
# [0.17279839]
# (1971, 10, 2)

# %%
#now we bring in the keras tensorflow model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.losses import MeanSquaredLogarithmicError, MeanSquaredError
from tensorflow.keras.utils import plot_model

#from keras_visualizer import visualizer

from math import pow, floor
import time

# %%
# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.00001
    drop = 0.5
    epochs_drop = 200
    lrate = initial_lrate * pow(drop, floor((1+epoch)/epochs_drop))
    return initial_lrate

def my_loss_fn(y_true, y_pred):
    return y_true - y_pred

# %%
#best params:
#Latent_dim:  50 L2 Regularizer:  0.0
#Final Val Loss: 0.14
#optimizer Adam
#batch size 100
#initial rate 0.0001
#drop 0.5
#epochs drop 50
reg_vals = [0.0]
optimizers = ['Adam']
val_results = []
batch_size = [100]
ndims = [50]
losses = [MeanSquaredError()]
for loss in losses:
    for ndim in ndims:
        for reg_val in reg_vals:
            for optimizer in optimizers:
                for batch in batch_size:
                    for i in range(0,1):
                        print('v.',i,'Latent_dim: ',ndim,'L2 Regularizer: ', reg_val,'Optimizer:',optimizer, 'Batch size:',batch)


                        t_start = time.time()
                        LATENT_DIM = ndim
                        BATCH_SIZE = batch
                        EPOCHS = 1000

                        lrate = LearningRateScheduler(step_decay)
                        model = Sequential()
                        model.add(LSTM(LATENT_DIM,return_sequences=True, input_shape=(T, 2), kernel_regularizer=l2(reg_val), recurrent_regularizer=l2(reg_val), bias_regularizer=l2(reg_val)))
                        model.add(LSTM(LATENT_DIM,return_sequences=True, kernel_regularizer=l2(reg_val), recurrent_regularizer=l2(reg_val), bias_regularizer=l2(reg_val)))
                        model.add(LSTM(LATENT_DIM, kernel_regularizer=l2(reg_val), recurrent_regularizer=l2(reg_val), bias_regularizer=l2(reg_val)))
                        #model.add(LSTM(32, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
                        model.add(Dense(HORIZON))
                        model.compile(optimizer=optimizer, loss=loss, 
                                     # metrics=['accuracy']
                                     )

                        earlystop = EarlyStopping(monitor="val_loss", min_delta=0.0, patience=5)
                        model_history = model.fit(
                        train_input["X"],
                        train_input["target"],
                        batch_size=BATCH_SIZE,
                        epochs=EPOCHS,
                        validation_data=(valid_inputs["X"], valid_inputs["target"]),
                        callbacks=[earlystop, lrate],
                        verbose=1,
                        )
                        
                        # list all data in history
                        #print(model_history.history.keys())
                        total_time = time.time()-t_start
                        #make a model picture
                        model.summary()
                        #model_vis = visualizer(model, format='png', view=True)
                        model_vis = plot_model(model, to_file='model.png')
                        # summarize history for loss
                        fig, ax = plt.subplots()
                        ax.plot(model_history.history['loss'])
                        ax.plot(model_history.history['val_loss'])

                        ax.set_ylabel('loss')
                        ax.set_xlabel('epoch')
                        fig.legend(['loss', 'val_loss'], loc='upper left')
                        #plt.show()
                        print('\tFinal Val Loss:',model_history.history['val_loss'][-1],' in: {}s'.format(total_time))
                        if(model_history.history['val_loss'][-1] < 1.0):
                            val_results.append((ndim,reg_val,model_history.history['val_loss'][-1],optimizer,total_time,batch,fig,model_vis))
                        else:
                            plt.close()
# Out:
# v. 0 Latent_dim:  50 L2 Regularizer:  0.0 Optimizer: Adam Batch size: 100
# Epoch 1/1000
# 20/20 [==============================] - 9s 158ms/step - loss: 1.0190 - val_loss: 1.2628
# Epoch 2/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 1.0275 - val_loss: 1.2575
# Epoch 3/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 1.0501 - val_loss: 1.2520
# Epoch 4/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 1.0371 - val_loss: 1.2469
# Epoch 5/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.9805 - val_loss: 1.2419
# Epoch 6/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.9750 - val_loss: 1.2368
# Epoch 7/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.9701 - val_loss: 1.2319
# Epoch 8/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.9517 - val_loss: 1.2270
# Epoch 9/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 1.0565 - val_loss: 1.2222
# Epoch 10/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.9415 - val_loss: 1.2174
# Epoch 11/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.9830 - val_loss: 1.2127
# Epoch 12/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.9375 - val_loss: 1.2078
# Epoch 13/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9694 - val_loss: 1.2030
# Epoch 14/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.9678 - val_loss: 1.1982
# Epoch 15/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.9911 - val_loss: 1.1935
# Epoch 16/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9952 - val_loss: 1.1886
# Epoch 17/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.8998 - val_loss: 1.1838
# Epoch 18/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 1.0078 - val_loss: 1.1789
# Epoch 19/1000
# 20/20 [==============================] - 1s 42ms/step - loss: 1.0150 - val_loss: 1.1742
# Epoch 20/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.9219 - val_loss: 1.1697
# Epoch 21/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8942 - val_loss: 1.1650
# Epoch 22/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.9640 - val_loss: 1.1601
# Epoch 23/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9419 - val_loss: 1.1554
# Epoch 24/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9168 - val_loss: 1.1509
# Epoch 25/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9200 - val_loss: 1.1464
# Epoch 26/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.9526 - val_loss: 1.1418
# Epoch 27/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.9410 - val_loss: 1.1376
# Epoch 28/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9065 - val_loss: 1.1335
# Epoch 29/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.9572 - val_loss: 1.1296
# Epoch 30/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.9197 - val_loss: 1.1255
# Epoch 31/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9401 - val_loss: 1.1220
# Epoch 32/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9411 - val_loss: 1.1187
# Epoch 33/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.9168 - val_loss: 1.1152
# Epoch 34/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9214 - val_loss: 1.1121
# Epoch 35/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.9063 - val_loss: 1.1093
# Epoch 36/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8693 - val_loss: 1.1059
# Epoch 37/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.9032 - val_loss: 1.1032
# Epoch 38/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8806 - val_loss: 1.1007
# Epoch 39/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.8908 - val_loss: 1.0980
# Epoch 40/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.8814 - val_loss: 1.0956
# Epoch 41/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.9703 - val_loss: 1.0930
# Epoch 42/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8542 - val_loss: 1.0908
# Epoch 43/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8879 - val_loss: 1.0888
# Epoch 44/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.9102 - val_loss: 1.0864
# Epoch 45/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8752 - val_loss: 1.0846
# Epoch 46/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8984 - val_loss: 1.0825
# Epoch 47/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8918 - val_loss: 1.0806
# Epoch 48/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.9023 - val_loss: 1.0783
# Epoch 49/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8624 - val_loss: 1.0768
# Epoch 50/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9043 - val_loss: 1.0750
# Epoch 51/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8956 - val_loss: 1.0731
# Epoch 52/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8969 - val_loss: 1.0714
# Epoch 53/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.9076 - val_loss: 1.0695
# Epoch 54/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.8717 - val_loss: 1.0677
# Epoch 55/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8717 - val_loss: 1.0662
# Epoch 56/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8953 - val_loss: 1.0642
# Epoch 57/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.9211 - val_loss: 1.0627
# Epoch 58/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8459 - val_loss: 1.0610
# Epoch 59/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.9111 - val_loss: 1.0591
# Epoch 60/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8782 - val_loss: 1.0576
# Epoch 61/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.9201 - val_loss: 1.0557
# Epoch 62/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.8185 - val_loss: 1.0542
# Epoch 63/1000
# 20/20 [==============================] - 1s 36ms/step - loss: 0.8472 - val_loss: 1.0524
# Epoch 64/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8996 - val_loss: 1.0504
# Epoch 65/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8688 - val_loss: 1.0492
# Epoch 66/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9288 - val_loss: 1.0472
# Epoch 67/1000
# 20/20 [==============================] - 1s 43ms/step - loss: 0.8385 - val_loss: 1.0454
# Epoch 68/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8479 - val_loss: 1.0438
# Epoch 69/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8798 - val_loss: 1.0423
# Epoch 70/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9069 - val_loss: 1.0407
# Epoch 71/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.9065 - val_loss: 1.0389
# Epoch 72/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8677 - val_loss: 1.0371
# Epoch 73/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8470 - val_loss: 1.0355
# Epoch 74/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8318 - val_loss: 1.0335
# Epoch 75/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8769 - val_loss: 1.0319
# Epoch 76/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8486 - val_loss: 1.0301
# Epoch 77/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8426 - val_loss: 1.0286
# Epoch 78/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8231 - val_loss: 1.0265
# Epoch 79/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8600 - val_loss: 1.0249
# Epoch 80/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8260 - val_loss: 1.0233
# Epoch 81/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8247 - val_loss: 1.0217
# Epoch 82/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8275 - val_loss: 1.0202
# Epoch 83/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.8712 - val_loss: 1.0180
# Epoch 84/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.8626 - val_loss: 1.0165
# Epoch 85/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.8097 - val_loss: 1.0148
# Epoch 86/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8219 - val_loss: 1.0130
# Epoch 87/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8072 - val_loss: 1.0111
# Epoch 88/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8389 - val_loss: 1.0095
# Epoch 89/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8195 - val_loss: 1.0076
# Epoch 90/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8595 - val_loss: 1.0058
# Epoch 91/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8081 - val_loss: 1.0042
# Epoch 92/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8649 - val_loss: 1.0021
# Epoch 93/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8438 - val_loss: 1.0004
# Epoch 94/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8388 - val_loss: 0.9988
# Epoch 95/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8239 - val_loss: 0.9972
# Epoch 96/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8721 - val_loss: 0.9951
# Epoch 97/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8406 - val_loss: 0.9932
# Epoch 98/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8551 - val_loss: 0.9916
# Epoch 99/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8926 - val_loss: 0.9897
# Epoch 100/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8456 - val_loss: 0.9875
# Epoch 101/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8898 - val_loss: 0.9859
# Epoch 102/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8450 - val_loss: 0.9843
# Epoch 103/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.7944 - val_loss: 0.9825
# Epoch 104/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8286 - val_loss: 0.9804
# Epoch 105/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.8020 - val_loss: 0.9787
# Epoch 106/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8356 - val_loss: 0.9770
# Epoch 107/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8292 - val_loss: 0.9753
# Epoch 108/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.7980 - val_loss: 0.9731
# Epoch 109/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8489 - val_loss: 0.9710
# Epoch 110/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8148 - val_loss: 0.9698
# Epoch 111/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8354 - val_loss: 0.9673
# Epoch 112/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8345 - val_loss: 0.9658
# Epoch 113/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.8099 - val_loss: 0.9638
# Epoch 114/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.7751 - val_loss: 0.9623
# Epoch 115/1000
# 20/20 [==============================] - 1s 43ms/step - loss: 0.8490 - val_loss: 0.9603
# Epoch 116/1000
# 20/20 [==============================] - 1s 35ms/step - loss: 0.8743 - val_loss: 0.9580
# Epoch 117/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.8301 - val_loss: 0.9566
# Epoch 118/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.8179 - val_loss: 0.9546
# Epoch 119/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.8227 - val_loss: 0.9529
# Epoch 120/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.8048 - val_loss: 0.9506
# Epoch 121/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.8400 - val_loss: 0.9490
# Epoch 122/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.8165 - val_loss: 0.9467
# Epoch 123/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.8105 - val_loss: 0.9451
# Epoch 124/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.8260 - val_loss: 0.9429
# Epoch 125/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7772 - val_loss: 0.9409
# Epoch 126/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7655 - val_loss: 0.9391
# Epoch 127/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7692 - val_loss: 0.9370
# Epoch 128/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.8256 - val_loss: 0.9350
# Epoch 129/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7719 - val_loss: 0.9331
# Epoch 130/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7819 - val_loss: 0.9315
# Epoch 131/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.8122 - val_loss: 0.9292
# Epoch 132/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7649 - val_loss: 0.9280
# Epoch 133/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.8105 - val_loss: 0.9255
# Epoch 134/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.8198 - val_loss: 0.9232
# Epoch 135/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7896 - val_loss: 0.9218
# Epoch 136/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.8180 - val_loss: 0.9194
# Epoch 137/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7890 - val_loss: 0.9178
# Epoch 138/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7790 - val_loss: 0.9160
# Epoch 139/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.8188 - val_loss: 0.9135
# Epoch 140/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7852 - val_loss: 0.9119
# Epoch 141/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7659 - val_loss: 0.9101
# Epoch 142/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7525 - val_loss: 0.9082
# Epoch 143/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7579 - val_loss: 0.9055
# Epoch 144/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7771 - val_loss: 0.9041
# Epoch 145/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7853 - val_loss: 0.9017
# Epoch 146/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7818 - val_loss: 0.8998
# Epoch 147/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.8435 - val_loss: 0.8975
# Epoch 148/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7931 - val_loss: 0.8957
# Epoch 149/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7910 - val_loss: 0.8935
# Epoch 150/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7687 - val_loss: 0.8912
# Epoch 151/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.8373 - val_loss: 0.8895
# Epoch 152/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.7718 - val_loss: 0.8878
# Epoch 153/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7660 - val_loss: 0.8857
# Epoch 154/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.7651 - val_loss: 0.8835
# Epoch 155/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7379 - val_loss: 0.8814
# Epoch 156/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7377 - val_loss: 0.8792
# Epoch 157/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7261 - val_loss: 0.8774
# Epoch 158/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7634 - val_loss: 0.8747
# Epoch 159/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7082 - val_loss: 0.8731
# Epoch 160/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7328 - val_loss: 0.8711
# Epoch 161/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.7310 - val_loss: 0.8686
# Epoch 162/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7213 - val_loss: 0.8671
# Epoch 163/1000
# 20/20 [==============================] - 1s 38ms/step - loss: 0.7817 - val_loss: 0.8647
# Epoch 164/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.7474 - val_loss: 0.8628
# Epoch 165/1000
# 20/20 [==============================] - 1s 26ms/step - loss: 0.7207 - val_loss: 0.8605
# Epoch 166/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7800 - val_loss: 0.8582
# Epoch 167/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7797 - val_loss: 0.8561
# Epoch 168/1000
# 20/20 [==============================] - 1s 26ms/step - loss: 0.7087 - val_loss: 0.8547
# Epoch 169/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7542 - val_loss: 0.8519
# Epoch 170/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7084 - val_loss: 0.8500
# Epoch 171/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7322 - val_loss: 0.8480
# Epoch 172/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7095 - val_loss: 0.8460
# Epoch 173/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.7366 - val_loss: 0.8431
# Epoch 174/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7222 - val_loss: 0.8411
# Epoch 175/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7205 - val_loss: 0.8393
# Epoch 176/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7070 - val_loss: 0.8368
# Epoch 177/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7103 - val_loss: 0.8349
# Epoch 178/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7010 - val_loss: 0.8330
# Epoch 179/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.6907 - val_loss: 0.8309
# Epoch 180/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.6950 - val_loss: 0.8285
# Epoch 181/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.7741 - val_loss: 0.8260
# Epoch 182/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.6630 - val_loss: 0.8248
# Epoch 183/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7314 - val_loss: 0.8221
# Epoch 184/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7225 - val_loss: 0.8200
# Epoch 185/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7313 - val_loss: 0.8177
# Epoch 186/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.7117 - val_loss: 0.8159
# Epoch 187/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.6976 - val_loss: 0.8134
# Epoch 188/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.6948 - val_loss: 0.8110
# Epoch 189/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.6922 - val_loss: 0.8095
# Epoch 190/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7156 - val_loss: 0.8074
# Epoch 191/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.6618 - val_loss: 0.8056
# Epoch 192/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.6712 - val_loss: 0.8026
# Epoch 193/1000
# 20/20 [==============================] - 1s 34ms/step - loss: 0.7269 - val_loss: 0.8002
# Epoch 194/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.6894 - val_loss: 0.7984
# Epoch 195/1000
# 20/20 [==============================] - 1s 33ms/step - loss: 0.6929 - val_loss: 0.7963
# Epoch 196/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.6756 - val_loss: 0.7943
# Epoch 197/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.6786 - val_loss: 0.7921
# Epoch 198/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.6837 - val_loss: 0.7898
# Epoch 199/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7021 - val_loss: 0.7878
# Epoch 200/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.7175 - val_loss: 0.7853
# Epoch 201/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.6971 - val_loss: 0.7839
# Epoch 202/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0
1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.5141 - val_loss: 0.5699
# Epoch 318/1000
# 20/20 [==============================] - 1s 26ms/step - loss: 0.5200 - val_loss: 0.5689
# Epoch 319/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4912 - val_loss: 0.5670
# Epoch 320/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.5139 - val_loss: 0.5660
# Epoch 321/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.5154 - val_loss: 0.5647
# Epoch 322/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.5210 - val_loss: 0.5633
# Epoch 323/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.5124 - val_loss: 0.5624
# Epoch 324/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4897 - val_loss: 0.5606
# Epoch 325/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.5069 - val_loss: 0.5593
# Epoch 326/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4790 - val_loss: 0.5575
# Epoch 327/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.5108 - val_loss: 0.5562
# Epoch 328/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.5218 - val_loss: 0.5547
# Epoch 329/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.5159 - val_loss: 0.5531
# Epoch 330/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.5002 - val_loss: 0.5519
# Epoch 331/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.4634 - val_loss: 0.5503
# Epoch 332/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.4656 - val_loss: 0.5490
# Epoch 333/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.4885 - val_loss: 0.5477
# Epoch 334/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4830 - val_loss: 0.5462
# Epoch 335/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.4896 - val_loss: 0.5449
# Epoch 336/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.4860 - val_loss: 0.5435
# Epoch 337/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4933 - val_loss: 0.5420
# Epoch 338/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4852 - val_loss: 0.5409
# Epoch 339/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.4773 - val_loss: 0.5402
# Epoch 340/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.4789 - val_loss: 0.5385
# Epoch 341/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.4596 - val_loss: 0.5364
# Epoch 342/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4671 - val_loss: 0.5352
# Epoch 343/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.4906 - val_loss: 0.5341
# Epoch 344/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4745 - val_loss: 0.5329
# Epoch 345/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4724 - val_loss: 0.5317
# Epoch 346/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4780 - val_loss: 0.5299
# Epoch 347/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4664 - val_loss: 0.5288
# Epoch 348/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4768 - val_loss: 0.5274
# Epoch 349/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4817 - val_loss: 0.5263
# Epoch 350/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4874 - val_loss: 0.5252
# Epoch 351/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4561 - val_loss: 0.5232
# Epoch 352/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4600 - val_loss: 0.5217
# Epoch 353/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4760 - val_loss: 0.5207
# Epoch 354/1000
# 20/20 [==============================] - 1s 27ms/step - loss: 0.4729 - val_loss: 0.5194
# Epoch 355/1000
# 20/20 [==============================] - 1s 37ms/step - loss: 0.4979 - val_loss: 0.5183
# Epoch 356/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4655 - val_loss: 0.5168
# Epoch 357/1000
# 20/20 [==============================] - 1s 26ms/step - loss: 0.4799 - val_loss: 0.5153
# Epoch 358/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4680 - val_loss: 0.5141
# Epoch 359/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4541 - val_loss: 0.5127
# Epoch 360/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4503 - val_loss: 0.5113
# Epoch 361/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4573 - val_loss: 0.5099
# Epoch 362/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4662 - val_loss: 0.5087
# Epoch 363/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.4446 - val_loss: 0.5075
# Epoch 364/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4434 - val_loss: 0.5059
# Epoch 365/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4348 - val_loss: 0.5049
# Epoch 366/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4381 - val_loss: 0.5036
# Epoch 367/1000
# 20/20 [==============================] - 1s 32ms/step - loss: 0.4416 - val_loss: 0.5025
# Epoch 368/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.4724 - val_loss: 0.5006
# Epoch 369/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.4424 - val_loss: 0.4995
# Epoch 370/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4347 - val_loss: 0.4987
# Epoch 371/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4485 - val_loss: 0.4974
# Epoch 372/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.4484 - val_loss: 0.4956
# Epoch 373/1000
# 20/20 [==============================] - 1s 31ms/step - loss: 0.4414 - val_loss: 0.4946
# Epoch 374/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.4344 - val_loss: 0.4935
# Epoch 375/1000
# 20/20 [==============================] - 1s 30ms/step - loss: 0.4448 - val_loss: 0.4920
# Epoch 376/1000
# 20/20 [==============================] - 1s 29ms/step - loss: 0.
1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1882 - val_loss: 0.1810
# Epoch 882/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1593 - val_loss: 0.1809
# Epoch 883/1000
# 20/20 [==============================] - 1s 26ms/step - loss: 0.1592 - val_loss: 0.1804
# Epoch 884/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1510 - val_loss: 0.1804
# Epoch 885/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1646 - val_loss: 0.1802
# Epoch 886/1000
# 20/20 [==============================] - 0s 21ms/step - loss: 0.1637 - val_loss: 0.1800
# Epoch 887/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1608 - val_loss: 0.1797
# Epoch 888/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1548 - val_loss: 0.1797
# Epoch 889/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1500 - val_loss: 0.1796
# Epoch 890/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1640 - val_loss: 0.1794
# Epoch 891/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1730 - val_loss: 0.1794
# Epoch 892/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1658 - val_loss: 0.1792
# Epoch 893/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1594 - val_loss: 0.1789
# Epoch 894/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1599 - val_loss: 0.1784
# Epoch 895/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1524 - val_loss: 0.1786
# Epoch 896/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1445 - val_loss: 0.1783
# Epoch 897/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1483 - val_loss: 0.1785
# Epoch 898/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1598 - val_loss: 0.1779
# Epoch 899/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1665 - val_loss: 0.1778
# Epoch 900/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1549 - val_loss: 0.1777
# Epoch 901/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1583 - val_loss: 0.1776
# Epoch 902/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1597 - val_loss: 0.1775
# Epoch 903/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1576 - val_loss: 0.1773
# Epoch 904/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1775 - val_loss: 0.1773
# Epoch 905/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1490 - val_loss: 0.1771
# Epoch 906/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1463 - val_loss: 0.1770
# Epoch 907/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1583 - val_loss: 0.1768
# Epoch 908/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1683 - val_loss: 0.1766
# Epoch 909/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1408 - val_loss: 0.1765
# Epoch 910/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1715 - val_loss: 0.1763
# Epoch 911/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1537 - val_loss: 0.1761
# Epoch 912/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1629 - val_loss: 0.1760
# Epoch 913/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1649 - val_loss: 0.1759
# Epoch 914/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1605 - val_loss: 0.1760
# Epoch 915/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1538 - val_loss: 0.1755
# Epoch 916/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1620 - val_loss: 0.1754
# Epoch 917/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1567 - val_loss: 0.1756
# Epoch 918/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1626 - val_loss: 0.1752
# Epoch 919/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1639 - val_loss: 0.1752
# Epoch 920/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1539 - val_loss: 0.1751
# Epoch 921/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1645 - val_loss: 0.1748
# Epoch 922/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1506 - val_loss: 0.1748
# Epoch 923/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1686 - val_loss: 0.1747
# Epoch 924/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1489 - val_loss: 0.1744
# Epoch 925/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1624 - val_loss: 0.1745
# Epoch 926/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1634 - val_loss: 0.1743
# Epoch 927/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1467 - val_loss: 0.1743
# Epoch 928/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1545 - val_loss: 0.1739
# Epoch 929/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1393 - val_loss: 0.1738
# Epoch 930/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1545 - val_loss: 0.1739
# Epoch 931/1000
# 20/20 [==============================] - 1s 28ms/step - loss: 0.1516 - val_loss: 0.1739
# Epoch 932/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1451 - val_loss: 0.1737
# Epoch 933/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1653 - val_loss: 0.1733
# Epoch 934/1000
# 20/20 [==============================] - 0s 18ms/step - loss: 0.1486 - val_loss: 0.1733
# Epoch 935/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1570 - val_loss: 0.1733
# Epoch 936/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1543 - val_loss: 0.1731
# Epoch 937/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1548 - val_loss: 0.1730
# Epoch 938/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1724 - val_loss: 0.1729
# Epoch 939/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1548 - val_loss: 0.1728
# Epoch 940/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1561 - val_loss: 0.1730
# Epoch 941/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1772 - val_loss: 0.1727
# Epoch 942/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1551 - val_loss: 0.1727
# Epoch 943/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1602 - val_loss: 0.1725
# Epoch 944/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1502 - val_loss: 0.1724
# Epoch 945/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1465 - val_loss: 0.1722
# Epoch 946/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1562 - val_loss: 0.1721
# Epoch 947/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1630 - val_loss: 0.1722
# Epoch 948/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1775 - val_loss: 0.1721
# Epoch 949/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1596 - val_loss: 0.1721
# Epoch 950/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1504 - val_loss: 0.1718
# Epoch 951/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1393 - val_loss: 0.1717
# Epoch 952/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1664 - val_loss: 0.1718
# Epoch 953/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1559 - val_loss: 0.1715
# Epoch 954/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1604 - val_loss: 0.1715
# Epoch 955/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1567 - val_loss: 0.1715
# Epoch 956/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1559 - val_loss: 0.1714
# Epoch 957/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1648 - val_loss: 0.1714
# Epoch 958/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1537 - val_loss: 0.1712
# Epoch 959/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1644 - val_loss: 0.1712
# Epoch 960/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1597 - val_loss: 0.1710
# Epoch 961/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1573 - val_loss: 0.1709
# Epoch 962/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1564 - val_loss: 0.1708
# Epoch 963/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1466 - val_loss: 0.1708
# Epoch 964/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1496 - val_loss: 0.1710
# Epoch 965/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1618 - val_loss: 0.1707
# Epoch 966/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1549 - val_loss: 0.1706
# Epoch 967/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1600 - val_loss: 0.1703
# Epoch 968/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1540 - val_loss: 0.1704
# Epoch 969/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1408 - val_loss: 0.1703
# Epoch 970/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1679 - val_loss: 0.1704
# Epoch 971/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1416 - val_loss: 0.1702
# Epoch 972/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1471 - val_loss: 0.1701
# Epoch 973/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1529 - val_loss: 0.1702
# Epoch 974/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1692 - val_loss: 0.1701
# Epoch 975/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1668 - val_loss: 0.1702
# Epoch 976/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1571 - val_loss: 0.1699
# Epoch 977/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1469 - val_loss: 0.1699
# Epoch 978/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1488 - val_loss: 0.1699
# Epoch 979/1000
# 20/20 [==============================] - 1s 26ms/step - loss: 0.1447 - val_loss: 0.1696
# Epoch 980/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1369 - val_loss: 0.1696
# Epoch 981/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1421 - val_loss: 0.1695
# Epoch 982/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1592 - val_loss: 0.1696
# Epoch 983/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1522 - val_loss: 0.1696
# Epoch 984/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1469 - val_loss: 0.1695
# Epoch 985/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1506 - val_loss: 0.1694
# Epoch 986/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1496 - val_loss: 0.1692
# Epoch 987/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1497 - val_loss: 0.1692
# Epoch 988/1000
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1437 - val_loss: 0.1692
# Epoch 989/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1544 - val_loss: 0.1690
# Epoch 990/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1431 - val_loss: 0.1689
# Epoch 991/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1555 - val_loss: 0.1691
# Epoch 992/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1676 - val_loss: 0.1691
# Epoch 993/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1608 - val_loss: 0.1689
# Epoch 994/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1388 - val_loss: 0.1688
# Epoch 995/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1622 - val_loss: 0.1690
# Epoch 996/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1549 - val_loss: 0.1689
# Epoch 997/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1558 - val_loss: 0.1687
# Epoch 998/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1492 - val_loss: 0.1687
# Epoch 999/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1404 - val_loss: 0.1687
# Epoch 1000/1000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1454 - val_loss: 0.1686
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 50)            10600
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 50)            20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 51,051
# Trainable params: 51,051
# Non-trainable params: 0
# _________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# 	Final Val Loss: 0.16860009729862213  in: 517.4076979160309s

# %%
#for result in val_results:
  #  print("ndim: ",result[0])
  #  print("reg_val: ",result[1])
  #  print("val_loss: ",result[2])
  #  print("optimizer: ",result[3])
df_results = pd.DataFrame(val_results, columns=['hidden_dimensions','L2_reg_val','final_val_loss','optimizer','training_time','batch_size','FIG','MODEL_VIS'])
res_grps = df_results.groupby('batch_size')
for batch in batch_size:
    print('Batch size: {}'.format(batch))
    df_batch = res_grps.get_group(batch).drop(['batch_size','hidden_dimensions','L2_reg_val'],axis=1)
    print('\tAvg final val loss: {:.2f}+-{:.2f}'.format(df_batch.final_val_loss.mean(),df_batch.final_val_loss.std()))
    print('\tAvg training time: {:.2f}+-{:.2f}'.format(df_batch.training_time.mean(),df_batch.training_time.std()))
    
for count,result in enumerate(val_results):
    result[-1].savefig('loss-curve_batch-size_{}_{}.png'.format(result[-4],count))
# Out:
# Batch size: 100
# 	Avg final val loss: 0.17+-nan
# 	Avg training time: 517.41+-nan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-0cd6637165d2> in <module>
#      13
#      14 for count,result in enumerate(val_results):
# ---> 15     result[-1].savefig('loss-curve_batch-size_{}_{}.png'.format(result[-4],count))
#
# AttributeError: 'NoneType' object has no attribute 'savefig'

# %%
df_results
# Out:
#    hidden_dimensions  L2_reg_val  final_val_loss optimizer  training_time  \
# 0                 50         0.0          0.1686      Adam     517.407698
#
#    batch_size              FIG MODEL_VIS
# 0         100  Figure(432x288)      None

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('mean squared-error')
plt.xlabel('epoch')
plt.legend(['training loss', 'validation loss'], loc='upper right')
plt.show()

# %%
#now we'll test
data_test_inputs = TimeSeriesTensor(test, "p2", HORIZON, tensor_structure)
#print(data_test_inputs['X'][0])
#print(data_test_inputs['target'][0])

predictions = model.predict(data_test_inputs["X"])
#print(predictions)
ev_data = create_evaluation_df(predictions, data_test_inputs, HORIZON, y_scaler)
ev_groups = ev_data.groupby('h')
#test.head()
gr1 = ev_groups.get_group('t+1')

# %%
gr1.describe()
# Out:
#        prediction      actual
# count  829.000000  829.000000
# mean     0.000016    0.000026
# std      0.000112    0.000118
# min     -0.000358   -0.000294
# 25%     -0.000051   -0.000051
# 50%      0.000016    0.000024
# 75%      0.000081    0.000095
# max      0.000510    0.000717

# %%
apes = []
for i in range(0, gr1.prediction.count()):
    if gr1.actual.iloc[i] == 0:
        continue
    ape = abs((gr1.prediction.iloc[i] - gr1.actual.iloc[i]) / gr1.actual.iloc[i])
    apes.append(ape)
    
mape1 = (sum(apes) / len(apes))

print('Evaluating GRU')
print("MAPE prediction 1 hour  ahead: {:.2%}".format(mape1))
# Out:
# Evaluating GRU
# MAPE prediction 1 hour  ahead: 652.56%

# %%
#lets plot our results
fig, ax = plt.subplots(figsize=(25,5))

ev_group = ev_groups.get_group('t+1')

ax.set_title('{time:.0f} hours predicting next 1 hour'.format(time=T))
ax.set_ylabel('calibration change')
ax.set_xlabel('FED firing time')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

ax.plot(ev_group.timestamp, ev_group.actual, 
         label='actual calibration', color='blue', linewidth=1, linestyle='solid')

ax.plot(ev_group.timestamp, ev_group.prediction, 
         label='predicted calibration', color='red', linewidth=1, linestyle='solid')
#legend
fig.legend(ncol=1, loc = (0.8,0.2))
fig.show()
# Out:
# /home/rusack/evans908/.local/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /home/rusack/evans908/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /home/rusack/evans908/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
####MAKE DIFF PLOT########
apdiff_series = ((ev_group.actual - ev_group.prediction) / ev_group.actual).abs()
fig3, ax3 = plt.subplots(figsize=(25,5))

ax3.set_ylabel('| Actual - Prediction / Actual |')
ax3.set_xlabel('FED firing time')
plt.setp(ax3.get_xticklabels(), rotation=30, horizontalalignment='right')
ax3.set_yscale('log')
ax3.set_ylim((.01,100.))
#actual data
ax3.plot(ev_group.timestamp, apdiff_series, 
     label='True value', color='green', linewidth=1, linestyle='solid')
#legend
fig3.legend(ncol=3, loc = 'upper center')

# %%
#our data is transformed to feed into the model. The diff step transforms the data by removing the large scale trends. We'll run that in reverse to look at the data with the trends.
ev_data_int = ev_data.copy()
ev_data_int['prediction'] = ev_data_int['prediction'].cumsum()
ev_data_int['actual'] = ev_data_int['actual'].cumsum()
ev_data.head()
# Out:
#             timestamp    h  prediction    actual
# 0 2018-10-29 02:19:59  t+1    0.000038  0.000141
# 1 2018-10-29 03:19:59  t+1    0.000138  0.000131
# 2 2018-10-29 04:19:59  t+1    0.000117  0.000130
# 3 2018-10-29 05:19:59  t+1    0.000108  0.000157
# 4 2018-10-29 06:19:59  t+1    0.000126  0.000159

# %%
#lets plot our results
fig10, ax13 = plt.subplots(figsize=(15,5))

ax13.set_title('{time:.0f} hours predicting next hour'.format(time=T))
ax13.set_ylabel('calibration value minus initial')
ax13.set_xlabel('calibration time')
plt.setp(ax13.get_xticklabels(), rotation=30, horizontalalignment='right')

ax13.plot(ev_data_int.timestamp, ev_data_int.actual, 
         label='actual calibration', color='blue', linewidth=2, linestyle='solid')

ax13.plot(ev_data_int.timestamp, ev_data_int.prediction, 
         label='predicted calibration', color='red', linewidth=2, linestyle='solid')

#lumi data on alternate y axis
#ax14 = ax13.twinx()
#ax14.set_ylabel('integrated luminosity (/ub)')
#
#ax14.plot(test_lumi_avg.index, test_lumi_avg, 
#         label='lumi averaged', color='limegreen', linewidth=1, linestyle='dashed')

#legend
fig10.legend(ncol=1, loc=(0.8,0.2))
#plt.ylim([-.05, ev_data_int.actual.max()*1.1])
fig10.show()
# Out:
# /home/rusack/evans908/.local/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /home/rusack/evans908/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /home/rusack/evans908/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
apes = []
for i in range(0, gr1.prediction.count()):
    if gr1.actual.iloc[i] == 0:
        continue
    ape = abs((gr1.prediction.iloc[i] - gr1.actual.iloc[i]) / gr1.actual.iloc[i])
    apes.append(ape)
    
mape1 = (sum(apes) / len(apes))
mape1
# Out:
# 6.525583745207721
